# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdotpy/MLstudy/blob/main/California_housing_pred_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #California house prediction

# %% [markdown]
# ## 1)  Load data

# %%
import pandas as pd
train_data=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
train_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
train_data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ## 2) prepare the data

# %% [markdown]
# ### data cleaning

# %%
train_data.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
train_data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# how many total missing values do we have?
import numpy as np
total_cells = np.prod(df.shape)
total_missing = df.isnull().sum().sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
#not required in this case
# Out:
# 0.0

# %% [markdown]
# ## split data (train and test sets)

# %%
from sklearn.model_selection import train_test_split
# no need to split data since we have a different testing data set, lets load that
test_data=pd.read_csv('/content/sample_data/california_housing_test.csv')
test_data.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# ## choosing Target and features to train our model

# %%
#choose Target
train_data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
y=train_data['median_house_value']
y.head()
# Out:
# 0    66900.0
# 1    80100.0
# 2    85700.0
# 3    73400.0
# 4    65500.0
# Name: median_house_value, dtype: float64

# %%
# now to choose our features X, for now lets keep all of the except the target
features=['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income']
X=train_data[features]
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income
# 0      1015.0       472.0         1.4936
# 1      1129.0       463.0         1.8200
# 2       333.0       117.0         1.6509
# 3       515.0       226.0         3.1917
# 4       624.0       262.0         1.9250

# %% [markdown]
# ## **Choose and Train model**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_model=RandomForestRegressor(random_state=1)
rf_model.fit(X,y)
# Out:
# RandomForestRegressor(random_state=1)

# %% [markdown]
# ## Prediction and evaluation

# %%
prediction=rf_model.predict(test_data[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income']])

# %%
test_data['median_house_value']
# Out:
# 0       344700.0
# 1       176500.0
# 2       270500.0
# 3       330000.0
# 4        81700.0
#           ...
# 2995    225000.0
# 2996    237200.0
# 2997     62000.0
# 2998    162500.0
# 2999    500001.0
# Name: median_house_value, Length: 3000, dtype: float64

# %% [markdown]
# ### MAE (mean absolute error) calculation for our regression model

# %%
### MAE (mean absolute error) calculation for our regression model
from sklearn.metrics import mean_absolute_error

rf_mae= mean_absolute_error(test_data['median_house_value'],prediction)
print(rf_mae)
# Out:
# 32193.693186666667
